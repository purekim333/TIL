# %% [markdown]
# # Pandas 에서 많이 사용하는 함수들
#
# [Here are the 8 Functions I Use the Most](https://towardsdatascience.com/i-have-been-using-pandas-for-3-years-here-are-the-8-functions-i-use-the-most-4e54f4db56560) 참고

# %% [markdown]
# ## 목차
#
# 1. [Pandas 로 csv 읽어오기](#1.-Pandas-로-csv-읽어오기)
#
#
# 2. [value_counts](#2.-value_counts) - 필드 별 개수 확인
#
#
# 3. [astype](#3.-astype) - 각 필드의 데이터 타입 확인
#
#
# 4. [isna & notna](#4.-isna-&-notna) - 결측치 확인
#
#
# 5. [dropna](#5.-dropna) - 결측치 제거
#
#
# 6. [fillna](#6.-fillna) - 결측치를 특정 값으로 처리
#
#
# 7. [groupby](#7.-groupby) - 특정 기준으로 그룹화하기
#
#
# 8. [unique & nunique](#8.-unique-&-nunique) - 고유값의 개수 확인하기
#
#
# 9. [정렬](#9.-정렬)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Pandas 로 csv 읽어오기
#
# __기본__: pandas 에서 지원하는 데이터 파일을 읽어오는 함수

# %%
df = pd.read_csv('data/test_data.CSV', encoding='cp949')
df.head()
# Out:
#     이름  나이 성별   직업    사는곳
# 0  김현우  25  남   교수   경상남도
# 1  이태현  28  여   군인   경상북도
# 2  박현준  36  남   기자  서울/경기
# 3  최성민  34  남  리포터    강원도
# 4  정준우  45  남   모델    강원도

# %% [markdown]
# __parse_dates__: 열 이름을 넣어주면 데이터 타입을 datatime64[ns]로 변환해준다.
# - `pd.to_datetime()` 함수로 datetime64 로 바꿀수도 있다.
# - '2019-01-01' 같은 `String` 형태의 자료형을 `datetime64` 로 바꿀 수 있다.

# %% [markdown]
# __usecols__: 여러 열 중 필요한 열만 가져온다.

# %%
df = pd.read_csv('data/test_data.CSV', encoding='cp949', usecols=['이름', '나이'])
df.head()
# Out:
#     이름  나이
# 0  김현우  25
# 1  이태현  28
# 2  박현준  36
# 3  최성민  34
# 4  정준우  45

# %% [markdown]
# __nrows__: 파일의 처음 n개의 행을 읽는다. 데이터 세트가 매우 큰 경우 유용하다.

# %%
df = pd.read_csv('data/test_data.CSV', encoding='cp949', nrows=10)
df.shape
# Out:
# (10, 5)

# %%
df
# Out:
#     이름  나이 성별    직업    사는곳
# 0  김현우  25  남    교수   경상남도
# 1  이태현  28  여    군인   경상북도
# 2  박현준  36  남    기자  서울/경기
# 3  최성민  34  남   리포터    강원도
# 4  정준우  45  남    모델    강원도
# 5  김준혁  67  여   개발자  서울/경기
# 6  이지훈  32  여   카텐더   충청북도
# 7  박준영  24  남  학원강사   전라북도
# 8  최준서  34  여   개발자    강원도
# 9  정준호  54  남    화가   충청북도

# %% [markdown]
# ##  2. value_counts
#
# 기본 함수에도 있던 함수. 범주형 열의 값 분포를 확인하는 데 유용하다.
# 발생 횟수와 함께 열의 고유 값을 반환한다.

# %%
df = pd.read_csv('data/test_data.CSV', encoding='cp949')
df["성별"].value_counts()
# Out:
# 성별
# 남    26
# 여    24
# Name: count, dtype: int64

# %% [markdown]
# `normalize` 를 통해 분포를 비율로 확인할 수 있다.

# %%
df["성별"].value_counts(normalize=True)
# Out:
# 성별
# 남    0.52
# 여    0.48
# Name: proportion, dtype: float64

# %% [markdown]
# ## 3. astype
#
# 데이터 분석 전 데이터 타입을 적절한 것으로 변환하는 건 거의 필수다.
# 어떤 함수들은 적절한 데이터 타입에서 훨씬 더 효율적으로 동작하거나, 일부 함수들은 아예 특정 데이터 타입에서만 사용할 수 있다.

# %%
df['이름'] = df['이름'].astype(str)
df.dtypes

# %% [markdown]
# string 형태는 object 로 출력된다.
#
# 여러 열의 데이터 타입을 한 번에 변경하려면 딕셔너리를 사용하면 된다.

# %%
df = df.astype({'성별': 'category', '직업': 'str'})
df.dtypes
# Out:
# 이름       object
# 나이        int64
# 성별     category
# 직업       object
# 사는곳      object
# dtype: object

# %% [markdown]
# ## 4. isna & notna
#
# [참고] - na 는 Numpy 의 Na(Not a Number)값을 의미함
#
# 데이터에 비어있는 값(결측값) 이 존재하는 경우가 있다.
#
# `test_data_has_null.CSV` 파일을 열어서 확인해보자.

# %%
df = pd.read_csv('data/test_data_has_null.CSV', encoding='cp949')
df.head()
# Out:
#     이름    나이 성별   직업    사는곳
# 0  김현우  25.0  남   교수   경상남도
# 1  이태현  28.0  여   군인   경상북도
# 2  박현준  36.0  남  NaN  서울/경기
# 3  최성민  34.0  남  리포터    강원도
# 4  정준우  45.0  남   모델    강원도

# %% [markdown]
# 위와 같이 결측값은 `NaN` 으로 출력된다.
#
# `isna` 함수와 `notna` 함수는 DataFrame 내의 결측값을 확인해서 `bool` 형식으로 반환하는 함수이다.
# `isna` 의 경우 결측값이면 `True` 반환, 정상값이면 `False` 를 반환하며,
# `notna` 의 경우 결측값이면 `False` 반환, 정상값이면 `True` 를 반환한다.
#
# __주의사항__: 무한값(`np.inf`) 나 띄워쓰기`' '`의 경우 결측값으로 판단하지 않는다.
#
# #### isna

# %%
df.head().isna()
# Out:
#       이름     나이     성별     직업    사는곳
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False  False  False   True  False
# 3  False  False  False  False  False
# 4  False  False  False  False  False

# %% [markdown]
# #### notna

# %%
df.head().notna()
# Out:
#      이름    나이    성별     직업   사는곳
# 0  True  True  True   True  True
# 1  True  True  True   True  True
# 2  True  True  True  False  True
# 3  True  True  True   True  True
# 4  True  True  True   True  True

# %% [markdown]
# #### 누락된 값의 수 구하기

# %%
df.isna().sum()

# %% [markdown]
# #### 행 별로 누락된 값의 수 구하기

# %%
df.isna().sum(axis=1)

# %% [markdown]
# __isnull() vs isna()__
#
# 동일한 함수이다.
# DB 에 저장된 결측치는 `null` 이라고 표시되는데, 이에 익숙한 사람들을 위해 `isna()` 의 별칭으로 `isnull()` 을 만들어 두었다.

# %% [markdown]
# ---
#
# 이러한 결측치를 처리하는 2가지 방법이 존재한다.
# - 1. 버리기(Drop) - dropna
# - 2. 채우기(Fill) - fillna

# %% [markdown]
# ## 5. dropna
#
# 첫 번째 방법으로, 누락된 값이 있는 행이나 열을 삭제하는 데 사용되는데, 다음 매개변수들이 존재한다.
#
# 참고사이트 - [pandas Docs - Dropna](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html)
#
# ### axis
# - __0__ or __'index'__ : 결측값이 있는 행을 삭제 -> default
# - __1__ or __'columns'__ : 결측값이 있는 열을 삭제

# %%
df = pd.read_csv('data/test_data_has_null.CSV', encoding='cp949')

# %%
df.isna().sum()

# %% [markdown]
# `dropna()` 는 DataFrame 을 반환한다.
# 원본 DataFrame 을 변경하고 싶으면 `inplace=True` 를 설정해준다

# %%
df.dropna(axis=0)
df.isna().sum()

# %%
df.dropna(axis=0, inplace=True)
df.isna().sum()

# %% [markdown]
# ### how
# - __any__: row 또는 column 에 NaN 값이 1개만 있어도 drop -> default
# - __all__: row 또는 column 에 있는 모든 값이 NaN 이어야 drop

# %%
df = pd.read_csv('data/test_data_has_null.CSV', encoding='cp949')
df.dropna(axis=0, how='all', inplace=True)
df.isna().sum()

# %% [markdown]
# ### thresh
# - 결측값이 아닌 열이 몇 개 이상일 경우 삭제하지 않는다는 임계치(기준)을 설정한다.
# - `axis=0, thresh=3` 일 때, 결측값이 아닌 열이 3개 이상이면 삭제하지 않는다.

# %%
df = pd.read_csv('data/test_data_has_null.CSV', encoding='cp949')
df
# Out:
#      이름    나이   성별       직업    사는곳
# 0   김현우  25.0    남       교수   경상남도
# 1   이태현  28.0    여       군인   경상북도
# 2   박현준  36.0    남      NaN  서울/경기
# 3   최성민  34.0    남      리포터    강원도
# 4   정준우  45.0    남       모델    강원도
# 5   김준혁  67.0    여      개발자  서울/경기
# 6   이지훈  32.0    여      NaN   충청북도
# 7   박준영  24.0    남     학원강사   전라북도
# 8   최준서  34.0    여      개발자    강원도
# 9   정준호  54.0    남       화가   충청북도
# 10  김지은  23.0    여     학원강사   경상북도
# 11  이수진  52.0    여      변호사   전라북도
# 12  박지현  64.0    남      개발자    강원도
# 13  최은지   NaN    여      법무사  서울/경기
# 14  정지원  76.0    남      변호사    강원도
# 15  김수빈  54.0    남     학원강사   충청북도
# 16  이은서  25.0    남       판사   경상북도
# 17  박지민  34.0    여      개발자   전라남도
# 18  최지연  62.0    여     학원강사   충청북도
# 19  정지윤  15.0    남       검사  서울/경기
# 20  김소은   NaN    여       검사   전라남도
# 21  이서현  34.0    남      미술가   전라북도
# 22  박수진  43.0    여      개발자   전라남도
# 23  최윤지   NaN    여      NaN   전라북도
# 24  정은지  65.0    여     학원강사   경상북도
# 25  김하은  78.0    여    게임기획자    NaN
# 26  이가영  89.0    남    프로게이머  서울/경기
# 27  박예린  45.0    남      개발자    제주도
# 28  최민서  35.0    남    감정평가사   경상북도
# 29  정은서  67.0    여      개발자    제주도
# 30  김태현  17.0    남  빅데이터전문가   전라북도
# 31  박현우  81.0    남      NaN    제주도
# 32  이민지  73.0    여     대학교수    NaN
# 33  박지우  64.0    여  빅데이터전문가    제주도
# 34  최수빈   NaN    남     대역배우  서울/경기
# 35  정은혜  75.0    여     학원강사   전라남도
# 36  김지원  34.0    남      도어맨  서울/경기
# 37  이지영  37.0    여  빅데이터전문가    강원도
# 38  박지수  54.0    남     패션모델   충청남도
# 39  최승현  26.0    남  휴대폰디자이너   경상북도
# 40  정윤서  47.0    여    웹디자이너   충청남도
# 41  김태우  23.0    여      개발자    강원도
# 42  이지민   NaN    여     웹개발자   경상북도
# 43  박수현  74.0    남      NaN  서울/경기
# 44  최지훈  25.0    남      건축가   경상북도
# 45  정은우  67.0    남  빅데이터전문가   충청남도
# 46  풀스택  37.0    남       모델  서울/경기
# 47  프론트  27.0  NaN      건축가   경상북도
# 48  백엔드  36.0    여      개발자  서울/경기
# 49  김장고  43.0    남      개발자  서울/경기

# %%
df = pd.read_csv('data/test_data_has_null.CSV', encoding='cp949')
df.dropna(axis=0, thresh=4, inplace=True)
df.isna().sum()
# Out:
# 이름     0
# 나이     4
# 성별     1
# 직업     4
# 사는곳    2
# dtype: int64

# %%
df.shape
# Out:
# (49, 5)

# %% [markdown]
# ## 6. fillna
#
# 결측값을 다른 적절한 값으로 채워준다.

# %%
df.head()

# %%
df['직업'].fillna('무직', inplace=True)
df.head()

# %%
df.isna().sum()

# %% [markdown]
# ## 7. groupby
#
# 열의 고유한 값을 기반으로 행을 그룹화한다.
# 독립된 그룹에 대하여 __별도로 데이터를 처리__ 하거나 __그룹별 통계량__ 을 확인하고자 할 때 유용하다.
#
# groupby 는 아래 3단계로 이루어 진다

# %% [markdown]
# ![groupby image](./data/pandas-groupby-split-apply-combine.svg)
#
# 이미지 출처: [www.w3resource.com](https://www.w3resource.com/)

# %% [markdown]
# __1. Split__: `.groupby()` 에서 정의한 컬럼 조건에 따라 독립된 그룹으로 나누는 단계. 위 사진에서는 `ID` 값을 기준으로 그룹으로 나누었고, 결과로 `X`, `Y`, `Z` 3개의 sub-group 으로 분할되었다.
#
# __2. Apply__: sub-group 에 그룹별 함수를 적용하는 단계. 예시에서는 합계(sum) 함수를 적용하여 각 그룹 별 총계가 합산된 결과를 확인할 수 있다.
#
# __3. Combine__: 각 sub-group 별로 함수가 적용된 결과를 종합하여 다시 하나의 테이블로 합침
#
# 이러한 과정을 이용하여 데이터 전처리/분석 시 유용하게 활용할 수 있다.
#
# 아래 예시는 `직업 별 평균 나이` 를 구하는 예시 코드이다.

# %%
df = pd.read_csv('data/test_data_has_null.CSV', encoding='cp949')

# %%
df.groupby('직업').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string '최민서' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.groupby('직업').mean()
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %% [markdown]
# __참고 - 경고문__: 위의 함수는 평균치를 구하는 함수이다. 평균치라는 것은 숫자에 대해서만(`numeric_only`) 작동이 가능하기 때문에, 숫자로 이루어진 열에만 계산을 적용하라는 뜻으로 `numeric_only` 옵션이 기본적으로 `True` 로 설정되어 있다.
# 미래 버전에서는 해당 옵션 기본값이 `False` 로 변하므로, 직접 `True` 로 설정하여 버그를 없애라는 경고 문구이다.
# 아래와 같이 옵션을 지정하면 버그가 없어진다.

# %%
df.groupby('직업').mean(numeric_only=True)
# Out:
#             나이
# 직업
# 감정평가사    35.00
# 개발자      45.60
# 건축가      26.00
# 검사       15.00
# 게임기획자    78.00
# 교수       25.00
# 군인       28.00
# 대역배우       NaN
# 대학교수     73.00
# 도어맨      34.00
# 리포터      34.00
# 모델       41.00
# 미술가      34.00
# 법무사        NaN
# 변호사      64.00
# 빅데이터전문가  46.25
# 웹개발자       NaN
# 웹디자이너    47.00
# 판사       25.00
# 패션모델     54.00
# 프로게이머    89.00
# 학원강사     50.50
# 화가       54.00
# 휴대폰디자이너  26.00

# %% [markdown]
# 위 코드는
# 1. 직업 별로 분할
# 2. 직업 별로 분할된 테이블의 숫자로 된 모든 열('나이') 의 평균 계산
# 3. 통합
# 을 통해 위와 같은 결과가 나온다
#
# 하나의 예시만 더 해보자.
#
# `직업 별 평균 나이` 에서 `성별을 추가적으로 구분하여 출력` 하는 예시 코드이다.

# %%
df.groupby(['직업', '성별']).mean(numeric_only=True).reset_index()
# Out:
#          직업 성별         나이
# 0     감정평가사  남  35.000000
# 1       개발자  남  50.666667
# 2       개발자  여  43.428571
# 3       건축가  남  25.000000
# 4        검사  남  15.000000
# 5        검사  여        NaN
# 6     게임기획자  여  78.000000
# 7        교수  남  25.000000
# 8        군인  여  28.000000
# 9      대역배우  남        NaN
# 10     대학교수  여  73.000000
# 11      도어맨  남  34.000000
# 12      리포터  남  34.000000
# 13       모델  남  41.000000
# 14      미술가  남  34.000000
# 15      법무사  여        NaN
# 16      변호사  남  76.000000
# 17      변호사  여  52.000000
# 18  빅데이터전문가  남  42.000000
# 19  빅데이터전문가  여  50.500000
# 20     웹개발자  여        NaN
# 21    웹디자이너  여  47.000000
# 22       판사  남  25.000000
# 23     패션모델  남  54.000000
# 24    프로게이머  남  89.000000
# 25     학원강사  남  39.000000
# 26     학원강사  여  56.250000
# 27       화가  남  54.000000
# 28  휴대폰디자이너  남  26.000000

# %% [markdown]
# 이와 같이 여러 그룹으로 구분하여, 여러가지 통계적인 계산이나 수학 연산 등이 가능하다.
# 아래 Docs 를 참고하여 여러 예제 코드를 사용해보자.
#
# [Pandas Docs - Groupby](https://pandas.pydata.org/docs/reference/groupby.html) 참고

# %% [markdown]
# ## 8. unique & nunique
# - __unique__: 고유값의 종류를 모두 출력
# - __nunique__: 고유값의 개수를 반환

# %%
df['직업'].unique()
# Out:
# array(['교수', '군인', nan, '리포터', '모델', '개발자', '학원강사', '화가', '변호사', '법무사',
#        '판사', '검사', '미술가', '게임기획자', '프로게이머', '감정평가사', '빅데이터전문가', '대학교수',
#        '대역배우', '도어맨', '패션모델', '휴대폰디자이너', '웹디자이너', '웹개발자', '건축가'],
#       dtype=object)

# %%
df['직업'].nunique()
# Out:
# 24

# %% [markdown]
# ## 9. 정렬
# - `sort_values()` 함수를 사용한다

# %% [markdown]
# 9.1. 정렬의 기준은 기본적으로 오름차순이다

# %%
df['직업'].sort_values()
# Out:
# 28      감정평가사
# 49        개발자
# 41        개발자
# 5         개발자
# 29        개발자
# 8         개발자
# 27        개발자
# 48        개발자
# 12        개발자
# 22        개발자
# 17        개발자
# 47        건축가
# 44        건축가
# 20         검사
# 19         검사
# 25      게임기획자
# 0          교수
# 1          군인
# 34       대역배우
# 32       대학교수
# 36        도어맨
# 3         리포터
# 46         모델
# 4          모델
# 21        미술가
# 13        법무사
# 11        변호사
# 14        변호사
# 45    빅데이터전문가
# 30    빅데이터전문가
# 33    빅데이터전문가
# 37    빅데이터전문가
# 42       웹개발자
# 40      웹디자이너
# 16         판사
# 38       패션모델
# 26      프로게이머
# 15       학원강사
# 35       학원강사
# 7        학원강사
# 10       학원강사
# 24       학원강사
# 18       학원강사
# 9          화가
# 39    휴대폰디자이너
# 2         NaN
# 6         NaN
# 23        NaN
# 31        NaN
# 43        NaN
# Name: 직업, dtype: object

# %% [markdown]
# 9.2. 내림차순은 `ascending=False` 옵션을 추가해준다.

# %%
df['직업'].sort_values(ascending=False)
# Out:
# 39    휴대폰디자이너
# 9          화가
# 10       학원강사
# 15       학원강사
# 35       학원강사
# 18       학원강사
# 7        학원강사
# 24       학원강사
# 26      프로게이머
# 38       패션모델
# 16         판사
# 40      웹디자이너
# 42       웹개발자
# 45    빅데이터전문가
# 37    빅데이터전문가
# 30    빅데이터전문가
# 33    빅데이터전문가
# 14        변호사
# 11        변호사
# 13        법무사
# 21        미술가
# 46         모델
# 4          모델
# 3         리포터
# 36        도어맨
# 32       대학교수
# 34       대역배우
# 1          군인
# 0          교수
# 25      게임기획자
# 20         검사
# 19         검사
# 44        건축가
# 47        건축가
# 29        개발자
# 27        개발자
# 22        개발자
# 17        개발자
# 41        개발자
# 12        개발자
# 8         개발자
# 5         개발자
# 48        개발자
# 49        개발자
# 28      감정평가사
# 2         NaN
# 6         NaN
# 23        NaN
# 31        NaN
# 43        NaN
# Name: 직업, dtype: object

# %% [markdown]
# 9.3. 모든 컬럼을 보기 위해서는 `by` 옵션을 활용한다.

# %%
df.sort_values(by=['나이'])
# Out:
#      이름    나이   성별       직업    사는곳
# 19  정지윤  15.0    남       검사  서울/경기
# 30  김태현  17.0    남  빅데이터전문가   전라북도
# 10  김지은  23.0    여     학원강사   경상북도
# 41  김태우  23.0    여      개발자    강원도
# 7   박준영  24.0    남     학원강사   전라북도
# 16  이은서  25.0    남       판사   경상북도
# 44  최지훈  25.0    남      건축가   경상북도
# 0   김현우  25.0    남       교수   경상남도
# 39  최승현  26.0    남  휴대폰디자이너   경상북도
# 47  프론트  27.0  NaN      건축가   경상북도
# 1   이태현  28.0    여       군인   경상북도
# 6   이지훈  32.0    여      NaN   충청북도
# 17  박지민  34.0    여      개발자   전라남도
# 21  이서현  34.0    남      미술가   전라북도
# 3   최성민  34.0    남      리포터    강원도
# 8   최준서  34.0    여      개발자    강원도
# 36  김지원  34.0    남      도어맨  서울/경기
# 28  최민서  35.0    남    감정평가사   경상북도
# 48  백엔드  36.0    여      개발자  서울/경기
# 2   박현준  36.0    남      NaN  서울/경기
# 46  풀스택  37.0    남       모델  서울/경기
# 37  이지영  37.0    여  빅데이터전문가    강원도
# 22  박수진  43.0    여      개발자   전라남도
# 49  김장고  43.0    남      개발자  서울/경기
# 27  박예린  45.0    남      개발자    제주도
# 4   정준우  45.0    남       모델    강원도
# 40  정윤서  47.0    여    웹디자이너   충청남도
# 11  이수진  52.0    여      변호사   전라북도
# 9   정준호  54.0    남       화가   충청북도
# 38  박지수  54.0    남     패션모델   충청남도
# 15  김수빈  54.0    남     학원강사   충청북도
# 18  최지연  62.0    여     학원강사   충청북도
# 33  박지우  64.0    여  빅데이터전문가    제주도
# 12  박지현  64.0    남      개발자    강원도
# 24  정은지  65.0    여     학원강사   경상북도
# 45  정은우  67.0    남  빅데이터전문가   충청남도
# 5   김준혁  67.0    여      개발자  서울/경기
# 29  정은서  67.0    여      개발자    제주도
# 32  이민지  73.0    여     대학교수    NaN
# 43  박수현  74.0    남      NaN  서울/경기
# 35  정은혜  75.0    여     학원강사   전라남도
# 14  정지원  76.0    남      변호사    강원도
# 25  김하은  78.0    여    게임기획자    NaN
# 31  박현우  81.0    남      NaN    제주도
# 26  이가영  89.0    남    프로게이머  서울/경기
# 13  최은지   NaN    여      법무사  서울/경기
# 20  김소은   NaN    여       검사   전라남도
# 23  최윤지   NaN    여      NaN   전라북도
# 34  최수빈   NaN    남     대역배우  서울/경기
# 42  이지민   NaN    여     웹개발자   경상북도

# %% [markdown]
# 9.4. 두 가지 이상의 정렬을 하는 방법은 다음과 같다.
# - 직업 별 오름차순, 나이 별 내림차순
# - ascending 옵션을 정렬 필드 순서대로 각각 지정해준다.

# %%
df.sort_values(by=['직업', '나이'], ascending=[True, False])
# Out:
#      이름    나이   성별       직업    사는곳
# 28  최민서  35.0    남    감정평가사   경상북도
# 5   김준혁  67.0    여      개발자  서울/경기
# 29  정은서  67.0    여      개발자    제주도
# 12  박지현  64.0    남      개발자    강원도
# 27  박예린  45.0    남      개발자    제주도
# 22  박수진  43.0    여      개발자   전라남도
# 49  김장고  43.0    남      개발자  서울/경기
# 48  백엔드  36.0    여      개발자  서울/경기
# 8   최준서  34.0    여      개발자    강원도
# 17  박지민  34.0    여      개발자   전라남도
# 41  김태우  23.0    여      개발자    강원도
# 47  프론트  27.0  NaN      건축가   경상북도
# 44  최지훈  25.0    남      건축가   경상북도
# 19  정지윤  15.0    남       검사  서울/경기
# 20  김소은   NaN    여       검사   전라남도
# 25  김하은  78.0    여    게임기획자    NaN
# 0   김현우  25.0    남       교수   경상남도
# 1   이태현  28.0    여       군인   경상북도
# 34  최수빈   NaN    남     대역배우  서울/경기
# 32  이민지  73.0    여     대학교수    NaN
# 36  김지원  34.0    남      도어맨  서울/경기
# 3   최성민  34.0    남      리포터    강원도
# 4   정준우  45.0    남       모델    강원도
# 46  풀스택  37.0    남       모델  서울/경기
# 21  이서현  34.0    남      미술가   전라북도
# 13  최은지   NaN    여      법무사  서울/경기
# 14  정지원  76.0    남      변호사    강원도
# 11  이수진  52.0    여      변호사   전라북도
# 45  정은우  67.0    남  빅데이터전문가   충청남도
# 33  박지우  64.0    여  빅데이터전문가    제주도
# 37  이지영  37.0    여  빅데이터전문가    강원도
# 30  김태현  17.0    남  빅데이터전문가   전라북도
# 42  이지민   NaN    여     웹개발자   경상북도
# 40  정윤서  47.0    여    웹디자이너   충청남도
# 16  이은서  25.0    남       판사   경상북도
# 38  박지수  54.0    남     패션모델   충청남도
# 26  이가영  89.0    남    프로게이머  서울/경기
# 35  정은혜  75.0    여     학원강사   전라남도
# 24  정은지  65.0    여     학원강사   경상북도
# 18  최지연  62.0    여     학원강사   충청북도
# 15  김수빈  54.0    남     학원강사   충청북도
# 7   박준영  24.0    남     학원강사   전라북도
# 10  김지은  23.0    여     학원강사   경상북도
# 9   정준호  54.0    남       화가   충청북도
# 39  최승현  26.0    남  휴대폰디자이너   경상북도
# 31  박현우  81.0    남      NaN    제주도
# 43  박수현  74.0    남      NaN  서울/경기
# 2   박현준  36.0    남      NaN  서울/경기
# 6   이지훈  32.0    여      NaN   충청북도
# 23  최윤지   NaN    여      NaN   전라북도
